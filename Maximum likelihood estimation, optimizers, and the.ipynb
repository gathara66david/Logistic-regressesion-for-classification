# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0.01, 1, 100)
y = np.log(x)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('log(x)')
plt.title('Logarithmic function')
plt.show()
